# %%
from sklearn.datasets import load_iris

# %%
data = load_iris(as_frame = True).frame
data.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target
# 0       0
# 1       0
# 2       0

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(data.iloc[:,:-1],data[['target']])
# Out:
# LinearRegression()

# %%
lr.predict(data.iloc[:,:-1])
# Out:
# array([[-8.25493616e-02],
#        [-4.01284476e-02],
#        [-4.86276768e-02],
#        [ 1.22998627e-02],
#        [-7.53667248e-02],
#        [ 5.82910066e-02],
#        [ 3.83367194e-02],
#        [-4.44863248e-02],
#        [ 1.98324281e-02],
#        [-8.21970989e-02],
#        [-1.01272512e-01],
#        [ 7.59348686e-04],
#        [-8.98630676e-02],
#        [-1.02503649e-01],
#        [-2.26652208e-01],
#        [-4.10494982e-02],
#        [-3.31670043e-02],
#        [-2.16241562e-02],
#        [-3.21980063e-02],
#        [-1.07834994e-02],
#        [-4.35196609e-02],
#        [ 5.41496547e-02],
#        [-1.22062394e-01],
#        [ 1.76835660e-01],
#        [ 6.93528569e-02],
#        [-5.59002750e-03],
#        [ 1.00228589e-01],
#        [-7.08754443e-02],
#        [-8.97319983e-02],
#        [ 1.99658314e-02],
#        [ 1.27831946e-02],
#        [ 3.26017444e-02],
#        [-1.55848342e-01],
#        [-1.55367344e-01],
#        [-2.12718935e-02],
# ...
